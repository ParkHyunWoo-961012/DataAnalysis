# %%
import FinanceDataReader as fdr
import pandas as pd
import requests
import datetime
from bs4 import BeautifulSoup

# %% [markdown]
# # 주식 산업별 거래량 데이터 모으기

# %%
url = "https://finance.naver.com/sise/sise_group.naver?type=upjong"
res = requests.get(url)
soup = BeautifulSoup(res.text, 'lxml')
soup = soup.find(class_="type_1").findAll('a')

page_num = [] # for finding stock name
industry_name = []
for i in range(len(soup)):
    if soup[i].string != "기타" and soup[i].string !="창업투자": # not need '기타' category because that have futures(선물) 
        page_num.append(soup[i].get("href"))
        industry_name.append(soup[i].string)
        
classfied_stock = {}
whole_stock_name = []
for i in range(len(page_num)):
    res = requests.get("https://finance.naver.com/" + page_num[i])
    soup = BeautifulSoup(res.text,'lxml')
    soup = soup.find('tbody').find_all('a')
    for j in range(len(soup)):
        stock_name = soup[j].getText()
        if stock_name != "":
            classfied_stock[stock_name] = industry_name[i]
            whole_stock_name.append(stock_name)
            
            
classfied_stock = pd.DataFrame(list(classfied_stock.items()),columns=['Stock_Name', 'Sectors'])
stock_code = pd.read_csv("stock_code.csv",encoding='CP949')
stock_code = stock_code[['단축코드','한글 종목약명']]
stock_code = stock_code[stock_code['한글 종목약명'].isin(whole_stock_name)]
stock_code = stock_code.rename(columns = {'한글 종목약명':'Stock_Name'})

classified_stock = classfied_stock.merge(stock_code,on='Stock_Name')

# %%
Sector_SC = None
Sector_Bio = None
Sector_Car = None
Sector_Gas = None
Sector_Game = None

# %%
target_sector = [Sector_SC,Sector_Bio,Sector_Car,Sector_Gas,Sector_Game]
sectors = ["반도체와반도체장비" , "제약" , "자동차" , "석유와가스" , "게임엔터테인먼트"]
stock_number = []
start_time = pd.Timestamp(year=2021, month=1, day=1)


for i in range(5):
    stock_code = classified_stock[classified_stock['Sectors'] == sectors[i]]['단축코드']
    stock_number.append(len(stock_code))
    for code in stock_code.values:
        stock_price = None
        stock_price = fdr.DataReader(code,start = "2021-11-09",exchange="KRX")
        stock_price['num_unlisted'] = 0
        stock_price.reset_index(inplace=True)
        min = stock_price['Date'].min()
        
        if code == stock_code.values[0]:
            target_sector[i] = stock_price
        else:
            if(len(target_sector[i])!=len(stock_price)):
                target_sector[i].loc[(target_sector[i]['Date']<min),'num_unlisted'] = target_sector[i].loc[(target_sector[i]['Date']<min),'num_unlisted'].values + 1
                target_sector[i].loc[(target_sector[i]['Date']>=min),'Volume'] = target_sector[i].loc[(target_sector[i]['Date']>=min),'Volume'].values+stock_price['Volume'].values
            else:
                target_sector[i]['Volume'] = target_sector[i]['Volume'] + stock_price['Volume']

# %%
result = None
for i in range(5):
    target_sector[i]['Volume'] = target_sector[i]['Volume']/(stock_number[i] - target_sector[i]['num_unlisted'])
    target_sector[i].rename(columns = {'Volume' : sectors[i]}, inplace = True)
    if i==0:
        result = target_sector[i]
    else:
        result = pd.merge(result,target_sector[i][[sectors[i]]+["Date"]],on="Date") 
        
result = result[["Date"]+sectors]

# %%
result
# Out:
#          Date     반도체와반도체장비             제약         자동차         석유와가스  \
# 0  2021-11-09  5.649465e+05  211612.152318  334540.000  4.199246e+06
# 1  2021-11-10  6.160860e+05  328178.688742  633348.875  3.205902e+06
# 2  2021-11-11  6.205119e+05  236115.913907  386556.000  1.870801e+06
# 3  2021-11-12  7.300724e+05  268352.894040  349315.375  1.382111e+06
# 4  2021-11-15  1.980573e+06  374094.258278  306255.000  2.468123e+06
# 5  2021-11-16  1.125604e+06  274601.119205  415799.125  1.240691e+06
# 6  2021-11-17  1.007052e+06  230441.688742  411796.250  2.036822e+06
# 7  2021-11-18  7.054886e+05  213678.026490  343106.125  2.270077e+06
# 8  2021-11-19  2.673618e+06  184157.231788  404964.250  1.163741e+06
# 9  2021-11-22  2.299030e+06  180847.682119  680434.250  1.156311e+06
# 10 2021-11-23  1.510108e+06  153619.033113  411270.875  9.490336e+05
# 11 2021-11-24  1.180147e+06  270941.079470  341799.375  3.140108e+06
# 12 2021-11-25  8.724869e+05  252715.152318  307125.125  1.739227e+06
# 13 2021-11-26  9.090241e+05  379664.728477  475577.750  1.386164e+06
# 14 2021-11-29  9.193733e+05  375603.874172  468770.500  1.351109e+07
# 15 2021-11-30  1.302524e+06  548990.503311  614786.625  2.956932e+06
# 16 2021-12-01  1.152649e+06  338905.543046  452863.625  1.252565e+06
# 17 2021-12-02  1.240497e+06  319094.933775  364885.250  9.913512e+05
# 18 2021-12-03  7.751625e+05  401519.986755  307134.500  1.217739e+06
# 19 2021-12-06  1.004013e+06  192615.331126  343962.125  1.429858e+06
# 20 2021-12-07  1.137589e+05   49239.556291   55820.750  1.413020e+05
#
#         게임엔터테인먼트
# 0   1.519503e+06
# 1   3.367234e+06
# 2   3.351900e+06
# 3   1.540664e+06
# 4   1.155049e+06
# 5   1.680001e+06
# 6   2.607056e+06
# 7   3.997607e+06
# 8   1.407674e+06
# 9   1.519572e+06
# 10  1.444910e+06
# 11  1.377559e+06
# 12  2.216025e+06
# 13  1.710628e+06
# 14  1.730746e+06
# 15  2.364256e+06
# 16  1.551698e+06
# 17  1.264960e+06
# 18  1.710830e+06
# 19  2.007724e+06
# 20  1.698519e+05

# %% [markdown]
# # ETF 거래량 모으기

# %%
US_SC_ETF = ['SOXX' ,'SMH' ,'SOXL']
US_BIO_ETF = ['ARKG', 'XLV', 'IBB']
US_CAR_ETF = ['CARZ', 'DRIV', 'ARKK']
US_GAS_ETF = ['USO','BOIL','XLE']
US_GM_ETF = ["ESPO" ,'HERO' ,'GAMR']

SC_ETF = None
BIO_ETF = None
CAR_ETF = None
GAS_ETF = None
GM_ETF = None
etf_price = None

Total_ETF = [US_SC_ETF,US_BIO_ETF,US_CAR_ETF,US_GAS_ETF,US_GM_ETF]
DF_ETF = [SC_ETF,BIO_ETF,CAR_ETF,GAS_ETF,GM_ETF]

# %%
for i in range(5):
    for etf_name in Total_ETF[i]:
        etf_price =fdr.DataReader(symbol = etf_name,start = "2021-11-09")
        #etf_price.drop(columns={"High","Low","Change"},inplace =True)
        if etf_name == Total_ETF[i][0]:
            DF_ETF[i] = etf_price
        else:
            DF_ETF[i] = DF_ETF[i] + etf_price
            
Natural_Gas = fdr.DataReader('NG',start = "2021-11-09")
USO = fdr.DataReader("USO",start = "2021-11-09")
DF_ETF[3]['NG_Volume'] = Natural_Gas['Volume']
DF_ETF[3]['USO_Volume'] = USO['Volume'] 
currency = fdr.DataReader("USD/KRW",start = "2021-11-09")
currency2 = fdr.DataReader("DX",start = "2021-11-09")

# %%
#etf_result = result
etf_result = DF_ETF[0]

etf_result["SC_ETF"] = DF_ETF[0]['Volume']
etf_result["BIO_ETF"] = DF_ETF[1]['Volume']
etf_result["CAR_ETF"] = DF_ETF[2]['Volume']
etf_result["GAS_ETF"] = DF_ETF[3]['Volume']
etf_result["NG_VOLUME"] = DF_ETF[3]['NG_Volume']
etf_result["USO_VOLUME"] = DF_ETF[3]['USO_Volume']
etf_result["GM_ETF"] = DF_ETF[4]['Volume']
etf_result['Exchange'] = currency['Close']
etf_result['DolloarIndex'] = currency2['Close']
etf_result = etf_result.drop(columns={"Close","Open","Volume"})


etf_result.reset_index(inplace=True)

# %%
ETF_Result = pd.merge(etf_result,result,on="Date")

# %%
ETF_Results = ETF_Result[ETF_Result.columns.difference(ETF_Result.columns[1:4])]

# %%
ETF_Results.to_csv("NewETF_Result.csv")

# %%
import FinanceDataReader as fdr
import pandas as pd

NYSE = fdr.StockListing("NYSE")
# Out:
#   0%|          | 0/3409 [00:00<?, ?it/s]
#   2%|▏         | 60/3409 [00:00<00:06, 512.45it/s]
#   4%|▎         | 120/3409 [00:00<00:06, 523.86it/s]
#   5%|▌         | 180/3409 [00:00<00:06, 490.79it/s]
#   7%|▋         | 240/3409 [00:00<00:06, 484.84it/s]
#   9%|▉         | 300/3409 [00:00<00:06, 465.79it/s]
#  11%|█         | 360/3409 [00:00<00:09, 335.12it/s]
#  12%|█▏        | 420/3409 [00:01<00:12, 239.37it/s]
#  14%|█▍        | 480/3409 [00:01<00:13, 215.10it/s]
#  16%|█▌        | 540/3409 [00:01<00:13, 211.54it/s]
#  18%|█▊        | 600/3409 [00:02<00:14, 195.07it/s]
#  19%|█▉        | 660/3409 [00:02<00:14, 194.18it/s]
#  21%|██        | 720/3409 [00:03<00:14, 189.11it/s]
#  23%|██▎       | 780/3409 [00:03<00:13, 195.49it/s]
#  25%|██▍       | 840/3409 [00:03<00:13, 185.84it/s]
#  26%|██▋       | 900/3409 [00:04<00:26, 95.95it/s]
#  28%|██▊       | 960/3409 [00:05<00:19, 125.16it/s]
#  30%|██▉       | 1020/3409 [00:05<00:14, 159.57it/s]
#  32%|███▏      | 1080/3409 [00:05<00:12, 187.04it/s]
#  33%|███▎      | 1140/3409 [00:05<00:10, 221.81it/s]
#  35%|███▌      | 1200/3409 [00:05<00:08, 256.90it/s]
#  37%|███▋      | 1260/3409 [00:05<00:07, 290.38it/s]
#  39%|███▊      | 1320/3409 [00:06<00:06, 306.79it/s]
gas_remove = ['XEC','GLP PR B','NGL PR B','GLP PR A','NGL PR C','RDS.A','PBR.A','RDS.B','COG','CIVI','EQT']
GAS_Stock = list(GAS_Stock)
for i in gas_remove:
    GAS_Stock.remove(i)
    
gm_remove = ['SOGO','QVCC','QVCD']
GM_Stock = list(GM_Stock)
for i in gm_remove:
    GM_Stock.remove(i)
    
Total_Stock = [SC_Stock]+[BIO_Stock]+[CAR_Stock]+[GAS_Stock]+[GM_Stock]

# %%
US_Sector_SC = None
US_Sector_Bio = None
US_Sector_Car = None
US_Sector_Gas = None
US_Sector_Game = None

target_sector = [US_Sector_SC,US_Sector_Bio,US_Sector_Car,US_Sector_Gas,US_Sector_Game]

# %%
US_Sector_Gas = None
US_Sector_Game = None
A = [None,None,None,US_Sector_Gas,US_Sector_Game]
for i in range(3,5):
    symbols = Total_Stock[i]
    for symbol in symbols:
        stock_price = None
        stock_price = fdr.DataReader(symbol,start = "2021-11-08",)
        stock_price['num_unlisted'] = 0
        stock_price.reset_index(inplace=True)
        
        if symbol == symbols[0]:
            A[i] = stock_price
            A[i].rename(columns ={'Volume':'Total_Volume'},inplace=True)
        else:
            A[i] = pd.merge(stock_price,A[i][['Date','Total_Volume']],on='Date',how='outer')
            A[i].fillna(0,inplace=True)
            
            if(len(target_sector[i])!=len(stock_price)):
                A[i].loc[A[i]['Volume']==0,'num_unlisted'] = A[i].loc[A[i]['Volume']==0,'num_unlisted'].values + 1
                A[i]['Total_Volume'] = A[i]['Total_Volume'] + A[i]['Volume']
            else:
                A[i]['Total_Volume'] = A[i]['Total_Volume'] + A[i]['Volume']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-f0448a6dc00c> in <module>
#       6     for symbol in symbols:
#       7         stock_price = None
# ----> 8         stock_price = fdr.DataReader(symbol,start = "2021-11-08",)
#       9         stock_price['num_unlisted'] = 0
#      10         stock_price.reset_index(inplace=True)
#
# /opt/anaconda3/lib/python3.7/site-packages/FinanceDataReader/data.py in DataReader(symbol, start, end, exchange, data_source)
#      39     # Investing
#      40     reader = InvestingDailyReader
# ---> 41     df = reader(symbol, start, end, exchange, data_source).read()
#      42     end = min([pd.to_datetime(end), datetime.today()])
#      43     while len(df) and df.index[-1] < end: # issues/30
#
# /opt/anaconda3/lib/python3.7/site-packages/FinanceDataReader/investing/data.py in read(self)
#      81
#      82         r = requests.post(url, data, headers=headers)
# ---> 83         dfs = pd.read_html(StringIO(r.text))
#      84         df = dfs[0]
#      85         if (len(df)==0) or ("No results found" == df.iloc[0]['Date']):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111         na_values=na_values,
#    1112         keep_default_na=keep_default_na,
# -> 1113         displayed_only=displayed_only,
#    1114     )
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     924     else:
#     925         assert retained is not None  # for mypy
# --> 926         raise retained
#     927
#     928     ret = []
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     904
#     905         try:
# --> 906             tables = p.parse_tables()
#     907         except ValueError as caught:
#     908             # if `io` is an io-like object, check if it's seekable
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in parse_tables(self)
#     220         list of parsed (header, body, footer) tuples from tables.
#     221         """
# --> 222         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     223         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     224
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse_tables(self, doc, match, attrs)
#     550
#     551         if not tables:
# --> 552             raise ValueError("No tables found")
#     553
#     554         result = []
#
# ValueError: No tables found

# %%
example = pd.read_csv("New3Sectors.csv")

# %%
symbols = Total_Stock[4]
for symbol in symbols[72:]:
        stock_price = None
        stock_price = fdr.DataReader(symbol,start = "2021-11-08")
        stock_price['num_unlisted'] = 0
        stock_price.reset_index(inplace=True)
        
        A[4] = pd.merge(stock_price,A[4][['Date','Total_Volume']],on='Date',how='outer')
        A[4].fillna(0,inplace=True)
            
        if(len(A[4])!=len(stock_price)):
            A[4].loc[A[4]['Volume']==0,'num_unlisted'] = A[4].loc[A[4]['Volume']==0,'num_unlisted'].values + 1
            A[4]['Total_Volume'] = A[4]['Total_Volume'] + A[4]['Volume']
        else:
            A[4]['Total_Volume'] = A[4]['Total_Volume'] + A[4]['Volume']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-c2b938f271f5> in <module>
#       6         stock_price.reset_index(inplace=True)
#       7
# ----> 8         A[4] = pd.merge(stock_price,A[4][['Date','Total_Volume']],on='Date',how='outer')
#       9         A[4].fillna(0,inplace=True)
#      10
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     116         copy=copy,
#     117         indicator=indicator,
# --> 118         validate=validate,
#     119     )
#     120     return op.get_result()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     696             self.right_join_keys,
#     697             self.join_names,
# --> 698         ) = self._get_merge_keys()
#     699
#     700         # validate the merge keys dtypes. We may need to coerce
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1106                         right_keys.append(rk)
#    1107                     if lk is not None:
# -> 1108                         left_keys.append(left._get_label_or_level_values(lk))
#    1109                         join_names.append(lk)
#    1110                     else:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'Date'

# %%
New3day_result
# Out:
#     Unnamed: 0        Date  US_SC_SECTOR_VOLUME  US_BIO_SECTOR_VOLUME  \
# 0            0  2021-11-08         2.535311e+06             5441681.6
# 1            1  2021-11-09         1.855284e+06             3733780.0
# 2            2  2021-11-10         1.832486e+06             4625422.0
# 3            3  2021-11-11         1.421550e+06             4023852.4
# 4            4  2021-11-12         1.259206e+06             4014367.6
# 5            5  2021-11-15         1.142189e+06             3685970.8
# 6            6  2021-11-16         1.514936e+06             4017942.0
# 7            7  2021-11-17         1.525636e+06             4149557.6
# 8            8  2021-11-18         1.871695e+06             4029785.6
# 9            9  2021-11-19         1.543554e+06             5190828.4
# 0           7.541805e+06
# 1           7.601800e+06
# 2           9.469705e+06
# 3           6.460999e+06
# 4           5.390027e+06
# 5           5.502127e+06
# 6           5.356496e+06
# 7           5.725131e+06
# 8           6.527017e+06
# 9           4.515432e+06
# 10          7.653284e+06
# 11          7.151545e+06
# 12          4.836546e+06
# 13          3.635173e+06
# 14          4.705409e+06
# 15          6.770574e+06
# 16          7.240575e+06
# 17          7.237803e+06
# 18          8.644019e+06
# 19          6.288359e+06

# %%
stock_number = []
for i in Total_Stock:
    stock_number.append(len(i))

# %%
sectors = ["US_SC_SECTOR_VOLUME" ,"US_BIO_SECTOR_VOLUME","US_CAR_SECTOR_VOLUME","US_GAS_SECTOR_VOLUME", "US_GM_SECTOR_VOLUME"]

# US_result = None

for i in range(3,5):
    A[4]['Total_Volume'] = A[4]['Total_Volume']/(stock_number[4] - A[4]['num_unlisted'])
    A[4].rename(columns = {'Total_Volume' : sectors[4]}, inplace = True)
#     if i==0:
#         US_result = A[i]
#     else:
#         US_result = pd.merge(US_result,A[i][[sectors[i]]+["Date"]],on="Date") 
        
#US_result = US_result[["Date"]+sectors]

# %%
US_result.to_csv("New3Sectors.csv")

# %%
New3day_result = pd.read_csv("New3Sectors.csv")
ETF_Results = pd.read_csv("NewETF_Result.csv")
New_Result = pd.read_csv("Us_Added_Stock_Info.csv")

# %%
#Total_Result = pd.merge(US_result,result,on='Date')
Total_Result = pd.merge(ETF_Results,Total_Result,on='Date')

# %%
add = pd.read_csv("BondRate.csv")
add['Date'] = pd.to_datetime(add['Date'])
Total_Result = pd.merge(add,Total_Result,on='Date')

# %%
Total_Result.sort_values(by =['Date'],ascending=False,inplace = True)
Total_Result.reset_index(drop=True,inplace=True)

# %%
NanColumns = ['DolloarIndex','NG_VOLUME']
for name in NanColumns:
    NanList  = Total_Result.loc[Total_Result[name].isna()].index
    for i in NanList:
        if i!=0:
            Total_Result.loc[i,name] = (Total_Result.loc[i+1,name] +Total_Result.loc[i-1,name])/2
        else:
            Total_Result.loc[i,name] = Total_Result.loc[i+1,name]

# %%
before_change = list(Total_Result.columns[-5:].values)

# %%
for i in range(5):
    Total_Result.rename(columns={before_change[i]:sectors[i]},inplace =True)

# %%
Total_Result.drop(columns=Total_Result.columns[11:16],inplace=True)

# %%
Total_Result.to_csv("Us_Added_Stock_Info.csv")

# %%
Total_Result= pd.read_csv("Us_Added_Stock_Info.csv")

# %%
Total_Result.drop(columns="Unnamed: 0", inplace= True)

# %%
sectors = ["US_SC_SECTOR_VOLUME" ,"US_BIO_SECTOR_VOLUME","US_CAR_SECTOR_VOLUME" , "US_GAS_SECTOR_VOLUME", "US_GM_SECTOR_VOLUME"]
Total_Result[['Date']+sectors]
# Out:
#            Date  US_SC_SECTOR_VOLUME  US_BIO_SECTOR_VOLUME  \
# 0    2021-01-04         1.943012e+06             4751732.4
# 1    2021-01-05         1.567917e+06             4572254.8
# 2    2021-01-06         1.774856e+06             4902517.2
# 3    2021-01-07         1.901702e+06             3893866.8
# 4    2021-01-08         2.392240e+06             4111595.6
# ..          ...                  ...                   ...
# 206  2021-11-11         1.421550e+06             4023852.4
# 207  2021-11-12         1.259206e+06             4014367.6
# 208  2021-11-15         1.142189e+06             3685970.8
# 209  2021-11-16         1.514936e+06             4017942.0
# 210  2021-11-17         1.525636e+06             4149557.6
#
#      US_CAR_SECTOR_VOLUME  US_GAS_SECTOR_VOLUME  US_GM_SECTOR_VOLUME
# 0            1.293087e+07          3.538662e+06         2.507433e+06
# 1            9.395011e+06          5.654613e+06         2.165651e+06
# 2            1.111446e+07          5.803685e+06         2.303577e+06
# 3            8.299572e+06          3.772788e+06         2.439438e+06
# 4            1.032720e+07          3.450589e+06         2.391136e+06
# ..                    ...                   ...                  ...
# 206          6.460999e+06          2.535479e+06         4.158503e+06
# 207          5.390027e+06          2.310701e+06         3.290843e+06
# 208          5.502127e+06          2.530865e+06         2.573064e+06
# 209          5.356496e+06          2.428729e+06         3.093370e+06
# 210          5.725131e+06          2.725787e+06         2.922732e+06
#
# [211 rows x 6 columns]

# %%
Total_Result.columns[:-5]
# Out:
# Index(['Date', 'KBondRate', 'SC_ETF', 'BIO_ETF', 'CAR_ETF', 'GAS_ETF',
#        'NG_VOLUME', 'USO_VOLUME', 'GM_ETF', 'Exchange', 'DolloarIndex',
#        'US_SC_SECTOR_VOLUME', 'US_BIO_SECTOR_VOLUME', 'US_CAR_SECTOR_VOLUME',
#        'US_GAS_SECTOR_VOLUME', 'US_GM_SECTOR_VOLUME'],
#       dtype='object')

# %%
sectors = ["반도체와반도체장비" , "제약" , "자동차" , "석유와가스" , "게임엔터테인먼트"]
Total_Result[['Date']+sectors]
# Out:
#            Date     반도체와반도체장비            제약          자동차         석유와가스  \
# 0    2021-01-04  2.107285e+06  8.335759e+05  1822792.375  2.939573e+06
# 1    2021-01-05  1.715251e+06  1.203097e+06  1187411.625  3.210694e+06
# 2    2021-01-06  1.824799e+06  2.796216e+06   983732.000  5.121786e+06
# 3    2021-01-07  2.008111e+06  1.208024e+06  1104469.625  2.359454e+06
# 4    2021-01-08  2.171529e+06  9.520995e+05  6781590.875  2.176021e+06
# ..          ...           ...           ...          ...           ...
# 206  2021-11-11  6.205119e+05  2.361159e+05   386556.000  1.870801e+06
# 207  2021-11-12  7.300724e+05  2.683529e+05   349315.375  1.382111e+06
# 208  2021-11-15  1.980573e+06  3.740943e+05   306255.000  2.468123e+06
# 209  2021-11-16  1.125604e+06  2.746011e+05   415799.125  1.240691e+06
# 210  2021-11-17  1.007052e+06  2.304417e+05   411796.250  2.036822e+06
#
#          게임엔터테인먼트
# 0    4.667284e+05
# 1    4.302828e+05
# 2    5.988308e+05
# 3    5.879534e+05
# 4    7.291916e+05
# ..            ...
# 206  3.351900e+06
# 207  1.540664e+06
# 208  1.155049e+06
# 209  1.680001e+06
# 210  2.607056e+06
#
# [211 rows x 6 columns]

# %%
ETF_Result.to_csv("2020Data.csv")
